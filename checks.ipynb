# %%
# !pip install pandas --q

# %%
import requests
import pandas as pd
# Out:
# /Users/tobi/Documents/projects/de-learn/6_stream/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=100"

headers = {
    "accept": "application/json",
    "x-cg-demo-api-key": "CG-gyq1fbSbpEuNGBef51ksBHfB\t"
}

response = requests.get(url, headers=headers)

# %%
print(response.json())
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 96754, 'market_cap': 1913453367606, 'market_cap_rank': 1, 'fully_diluted_valuation': 2030782195783, 'total_volume': 49130796649, 'high_24h': 98926, 'low_24h': 96556, 'price_change_24h': -2009.715734321886, 'price_change_percentage_24h': -2.03486, 'market_cap_change_24h': -40340924768.621826, 'market_cap_change_percentage_24h': -2.06475, 'circulating_supply': 19786721.0, 'total_supply': 21000000.0, 'max_supply': 21000000.0, 'ath': 99645, 'ath_change_percentage': -2.9619, 'ath_date': '2024-11-22T19:35:49.770Z', 'atl': 67.81, 'atl_change_percentage': 142497.58477, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2024-11-24T14:29:21.057Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 3302
# ...

# %%
data = response.json()

df = pd.DataFrame(data)
csv_file = 'list.csv'
csv = df.to_csv(csv_file, index=False)

# %%
df_id = pd.read_csv('list.csv')
df_id
# Out:
#                 id symbol       name  \
# 0          bitcoin    btc    Bitcoin
# 1         ethereum    eth   Ethereum
# 2           tether   usdt     Tether
# 3           solana    sol     Solana
# 4      binancecoin    bnb        BNB
# ..             ...    ...        ...
# 95             eos    eos        EOS
# 96       jasmycoin  jasmy  JasmyCoin
# 97        lido-dao    ldo   Lido DAO
# 98          beam-2   beam       Beam
# 99  flare-networks    flr      Flare
#
#                                                 image  current_price  \
# 0   https://coin-images.coingecko.com/coins/images...   96754.000000
# 1   https://coin-images.coingecko.com/coins/images...    3302.450000
# 2   https://coin-images.coingecko.com/coins/images...       1.001000
# 3   https://coin-images.coingecko.com/coins/images...     245.690000
# 4   https://coin-images.coingecko.com/coins/images...     645.480000
# ..                                                ...            ...
# ...

# %%
# id = df['id'].tolist()
df_id_file = df_id['id']
df_id_file
# Out:
# 0            bitcoin
# 1           ethereum
# 2             tether
# 3             solana
# 4        binancecoin
#            ...
# 95               eos
# 96         jasmycoin
# 97          lido-dao
# 98            beam-2
# 99    flare-networks
# Name: id, Length: 100, dtype: object

# %%
df_id_file.to_csv('id.csv', index=False)
